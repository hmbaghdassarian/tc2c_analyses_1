# %%
import pandas as pd
import random
import numpy as np
import scanpy as sc
# import scipy
from tqdm import tqdm

data_path = '/data2/hratch/immune_CCI/covid/covid_atlas/'
load_h5 = True

# %%
pbmc_covid = sc.read_mtx(data_path + 'raw/GSE158055_covid19_counts.mtx.gz') # raw counts
if load_h5: 
    pch5 = sc.read_h5ad(data_path + 'raw/COVID19_ALL.h5ad') # load dataset
# pbmc_covid = sc.read_10x_mtx(data_path + 'raw/counts/')

print('Finished loading covid datasets')

# %%
# exclude samples with fewer than 2000 cells
md_cell = pd.read_csv(data_path + 'raw/GSE158055_cell_annotation.csv.gz')
n_samples = md_cell.sampleID.value_counts()
samples_to_keep = n_samples[n_samples > 2000].index.tolist()

# %%
md = pd.read_excel(data_path + 'raw/GSE158055_sample_metadata.xlsx', sheet_name = 0, skiprows=20)
md = md.iloc[range(304 - 20), range(25)]
md = md[md['Sample name'].isin(samples_to_keep)] # >2000 cellcs
md = md[md['characteristics: Sample type'].isin(['frozen PBMC', 'fresh PBMC'])] # pbmcs only

contexts = md['characteristics: CoVID-19 severity'].unique()
n_contexts = contexts.shape[0]

context_counts = md['characteristics: CoVID-19 severity'].value_counts() 
min_context_type = context_counts[context_counts == context_counts.min()].index.tolist()[0]
min_context_count = len(md[md['characteristics: CoVID-19 severity'] == min_context_type]['Patients'].unique())

max_samples = min_context_count*n_contexts

context_map = {context: md[md['characteristics: CoVID-19 severity'] == \
                           context][['Sample name', 'Patients']].reset_index(drop = True) for context in contexts}

# %%
# randomly select samples subsetted from the entire dataset
# make sure to choose an even number of each context
# make sure not to repeat patients within a context

n_iter = 1 # number of times to run subsetting
seed = 0

Samples = pd.DataFrame(columns = ['iteration', 'n_samples', 'sample_names'])
idx = 0

sample_iters = [3, 6, 12, 24, 36, 48, 60]#list(range(n_contexts, max_samples + 1, n_contexts))

for iteration in range(n_iter):
    for n_samples in sample_iters:
        cmap_temp = context_map.copy()
        n_sample_per_context = int(n_samples/n_contexts)
        samples = list()
        for context in contexts:
            df = context_map[context].sample(frac=1, random_state = seed).drop_duplicates(subset = 'Patients') # shuffle rows to randomly drop duplicates
            samples += df.sample(n = n_sample_per_context, random_state = seed)['Sample name'].tolist()
            seed += 1
        Samples.loc[idx,:] = [iteration, n_samples, samples]
        idx += 1

Samples['sample_names'] = Samples.sample_names.apply(lambda x: '; '.join(x))            
Samples.to_csv(data_path + 'interim/timing_inputs/samples_for_timing.csv')
# Out:
# /home/hratch/anaconda3/envs/cellchat/lib/python3.9/site-packages/pandas/core/internals/blocks.py:993: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   arr_value = np.array(value)

# %%
#cell_ids = pd.read_csv(data_path + 'raw/GSE158055_covid19_barcodes.tsv.gz', header = None)
gene_ids = pd.read_csv(data_path + 'raw/GSE158055_covid19_features.tsv.gz', header = None)
md_cell.set_index('cellName', drop = True, inplace = True)

pbmc_covid = pbmc_covid.transpose()

# %%
if load_h5:
    pbmc_covid.obs = pch5.obs
    pbmc_covid.var = pch5.var
else:
    pbmc_covid.obs = md_cell
    pbmc_covid.var = gene_ids.set_index(0, drop = True)

# %%
# split by sample id 

def flatten_list(t):
    return [item for sublist in t for item in sublist]

def create_raw_counts(sample_id):
    df = pbmc_covid[pbmc_covid.obs.sampleID == sample_id]
    sc.pp.filter_cells(df, min_genes=50) 
#     sc.pp.filter_genes(df, min_cells = 3) # avoid filtering genes, will need intersection of remaining genes, which filters to many out when subsequently filtering for LR pairs
    return df

sample_ids = list(set(flatten_list([sn.split('; ') for sn in Samples.sample_names.tolist()])))
sample_counts = {sample_id: create_raw_counts(sample_id) for sample_id in tqdm(sample_ids)}


min_cells_to_keep = min([df.n_obs for sample_id, df in sample_counts.items()])
# Out:
#   0%|          | 0/105 [00:00<?, ?it/s]Trying to set attribute `.obs` of view, copying.
#   1%|          | 1/105 [01:09<2:00:29, 69.51s/it]Trying to set attribute `.obs` of view, copying.
#   2%|▏         | 2/105 [01:09<49:19, 28.73s/it]  Trying to set attribute `.obs` of view, copying.
#   3%|▎         | 3/105 [03:08<1:58:56, 69.96s/it]Trying to set attribute `.obs` of view, copying.
#   4%|▍         | 4/105 [06:37<3:30:12, 124.88s/it]Trying to set attribute `.obs` of view, copying.
#   5%|▍         | 5/105 [07:14<2:35:13, 93.13s/it]

# %%
# seed = 21
seed += 1

# subset to min cells_to_keep and write to csv
cells_to_keep = list()
for sample_id in tqdm(sample_counts):
    random.seed(seed)
    df = sample_counts[sample_id]
    df = df[df.obs.index.isin(random.sample(df.obs.index.tolist(), min_cells_to_keep))] # subset
#     df.to_df().to_csv(data_path + 'interim/umi_for_timing/' + sample_id + '.csv') # write
    df.to_df().to_hdf(data_path + 'interim/timing_inputs/umi_per_sample.h5', key = sample_id)
    cells_to_keep += df.obs.index.tolist()
    seed += 1

pbmc_covid.obs[pbmc_covid.obs.index.isin(cells_to_keep)].to_csv(data_path + 'interim/timing_inputs/metadata_for_timing.csv')

# %%
print('2')

# %%
print('2')

# %% [markdown]
# # Classification

# %%
sample_ids = md['Sample name'].unique().tolist()
pbmc_covid.obs[pbmc_covid.obs.sampleID.isin(sample_ids)].to_csv(data_path + 'interim/classification_inputs/metadata.csv')
sample_counts = {sample_id: create_raw_counts(sample_id) for sample_id in tqdm(sample_ids)}
# Out:
#   0%|          | 0/151 [00:00<?, ?it/s]Trying to set attribute `.obs` of view, copying.
#   1%|          | 1/151 [00:00<00:34,  4.32it/s]Trying to set attribute `.obs` of view, copying.
#   1%|▏         | 2/151 [00:00<00:28,  5.18it/s]Trying to set attribute `.obs` of view, copying.
#   2%|▏         | 3/151 [00:00<00:41,  3.54it/s]Trying to set attribute `.obs` of view, copying.
#   3%|▎         | 4/151 [00:01<01:30,  1.62it/s]Trying to set attribute `.obs` of view, copying.
#   3%|▎         | 5/151 [00:02<01:51,  1.31it/s]Trying to set attribute `.obs` of view, copying.
#   4%|▍         | 6/151 [00:03<01:58,  1.22it/s]Trying to set attribute `.obs` of view, copying.
#   5%|▍         | 7/151 [00:04<01:58,  1.22it/s]Trying to set attribute `.obs` of view, copying.
#   5%|▌         | 8/151 [00:05<01:40,  1.42it/s]Trying to set attribute `.obs` of view, copying.
#   6%|▌         | 9/151 [00:05<01:33,  1.52it/s]Trying to set attribute `.obs` of view, copying.
#   7%|▋         | 10/151 [00:08<02:57,  1.26s/it]Trying to set attribute `.obs` of view, copying.
#   7%|▋         | 11/151 [00:09<03:07,  1.34s/it]Trying to set attribute `.obs` of view, copying.
#   8%|▊         | 12/151 [00:10<02:30,  1.08s/it]Trying to set attribute `.obs` of view, copying.
#   9%|▊         | 13/151 [00:11<02:27,  1.07s/it]Trying to set attribute `.obs` of view, copying.
#   9%|▉         | 14/151 [00:11<02:01,  1.13it/s]Trying to set attribute `.obs` of view, copying.
#  10%|▉         | 15/151 [00:12<01:35,  1.42it/s]Trying to set attribute `.obs` of view, copying.
#  11%|█         | 16/151 [00:13<01:54,  1.18it/s]Trying to set attribute `.obs` of view, copying.
#  11%|█▏        | 17/151 [00:16<03:47,  1.70s/it]Trying to set attribute `.obs` of view, copying.
#  12%|█▏        | 18/151 [00:20<04:40,  2.11s/it]Trying to set attribute `.obs` of view, copying.
#  13%|█▎        | 19/151 [00:20<03:49,  1.74s/it]Trying to set attribute `.obs` of view, copying.
#  13%|█▎        | 20/151 [00:21<03:07,  1.43s/it]Trying to set attribute `.obs` of view, copying.
#  14%|█▍        | 21/151 [00:21<02:19,  1.07s/it]Trying to set attribute `.obs` of view, copying.
#  15%|█▍        | 22/151 [00:22<01:50,  1.16it/s]Trying to set attribute `.obs` of view, copying.
#  15%|█▌        | 23/151 [00:23<02:05,  1.02it/s]Trying to set attribute `.obs` of view, copying.
#  16%|█▌        | 24/151 [00:23<01:36,  1.32it/s]Trying to set attribute `.obs` of view, copying.
#  17%|█▋        | 25/151 [00:24<01:21,  1.54it/s]Trying to set attribute `.obs` of view, copying.
#  17%|█▋        | 26/151 [00:24<01:09,  1.79it/s]Trying to set attribute `.obs` of view, copying.
#  18%|█▊        | 27/151 [00:25<01:39,  1.25it/s]Trying to set attribute `.obs` of view, copying.
#  19%|█▊        | 28/151 [00:26<01:32,  1.33it/s]Trying to set attribute `.obs` of view, copying.
#  19%|█▉        | 29/151 [00:27<01:58,  1.03it/s]Trying to set attribute `.obs` of view, copying.
#  20%|█▉        | 30/151 [00:28<01:38,  1.23it/s]Trying to set attribute `.obs` of view, copying.
#  21%|██        | 31/151 [00:36<06:08,  3.07s/it]Trying to set attribute `.obs` of view, copying.
#  21%|██        | 32/151 [00:37<04:59,  2.51s/it]Trying to set attribute `.obs` of view, copying.
#  22%|██▏       | 33/151 [00:43<06:57,  3.54s/it]Trying to set attribute `.obs` of view, copying.
#  23%|██▎       | 34/151 [00:46<06:05,  3.12s/it]Trying to set attribute `.obs` of view, copying.
#  23%|██▎       | 35/151 [00:57<10:53,  5.64s/it]Trying to set attribute `.obs` of view, copying.
#  24%|██▍       | 36/151 [00:57<07:38,  3.99s/it]Trying to set attribute `.obs` of view, copying.
#  25%|██▍       | 37/151 [00:58<05:36,  2.95s/it]Trying to set attribute `.obs` of view, copying.
#  25%|██▌       | 38/151 [00:58<04:08,  2.20s/it]Trying to set attribute `.obs` of view, copying.
#  26%|██▌       | 39/151 [00:59<03:30,  1.88s/it]Trying to set attribute `.obs` of view, copying.
#  26%|██▋       | 40/151 [01:01<03:07,  1.69s/it]Trying to set attribute `.obs` of view, copying.
#  27%|██▋       | 41/151 [01:01<02:19,  1.27s/it]Trying to set attribute `.obs` of view, copying.
#  28%|██▊       | 42/151 [01:04<03:32,  1.95s/it]Trying to set attribute `.obs` of view, copying.
#  28%|██▊       | 43/151 [01:05<02:34,  1.43s/it]Trying to set attribute `.obs` of view, copying.
#  29%|██▉       | 44/151 [01:05<01:51,  1.04s/it]Trying to set attribute `.obs` of view, copying.
#  30%|██▉       | 45/151 [01:05<01:23,  1.28it/s]Trying to set attribute `.obs` of view, copying.
#  30%|███       | 46/151 [01:05<01:04,  1.63it/s]Trying to set attribute `.obs` of view, copying.
#  31%|███       | 47/151 [01:05<00:47,  2.18it/s]Trying to set attribute `.obs` of view, copying.
#  32%|███▏      | 48/151 [01:05<00:36,  2.81it/s]Trying to set attribute `.obs` of view, copying.
#  32%|███▏      | 49/151 [01:05<00:30,  3.40it/s]Trying to set attribute `.obs` of view, copying.
#  33%|███▎      | 50/151 [01:08<01:23,  1.21it/s]Trying to set attribute `.obs` of view, copying.
#  34%|███▍      | 51/151 [01:10<02:04,  1.25s/it]Trying to set attribute `.obs` of view, copying.
#  34%|███▍      | 52/151 [01:10<01:40,  1.02s/it]Trying to set attribute `.obs` of view, copying.
#  35%|███▌      | 53/151 [01:10<01:14,  1.32it/s]Trying to set attribute `.obs` of view, copying.
#  36%|███▌      | 54/151 [01:11<00:57,  1.68it/s]Trying to set attribute `.obs` of view, copying.
#  36%|███▋      | 55/151 [01:15<02:37,  1.64s/it]Trying to set attribute `.obs` of view, copying.
#  37%|███▋      | 56/151 [01:20<04:17,  2.71s/it]Trying to set attribute `.obs` of view, copying.
#  38%|███▊      | 57/151 [01:21<03:19,  2.13s/it]Trying to set attribute `.obs` of view, copying.
#  38%|███▊      | 58/151 [01:24<03:38,  2.35s/it]Trying to set attribute `.obs` of view, copying.
#  39%|███▉      | 59/151 [01:28<04:32,  2.96s/it]Trying to set attribute `.obs` of view, copying.
#  40%|███▉      | 60/151 [01:29<03:45,  2.48s/it]Trying to set attribute `.obs` of view, copying.
#  40%|████      | 61/151 [01:30<03:04,  2.06s/it]Trying to set attribute `.obs` of view, copying.
#  41%|████      | 62/151 [01:37<04:52,  3.29s/it]Trying to set attribute `.obs` of view, copying.
#  42%|████▏     | 63/151 [01:37<03:35,  2.45s/it]Trying to set attribute `.obs` of view, copying.
#  42%|████▏     | 64/151 [01:50<08:16,  5.71s/it]Trying to set attribute `.obs` of view, copying.
#  43%|████▎     | 65/151 [02:00<09:54,  6.91s/it]Trying to set attribute `.obs` of view, copying.
#  44%|████▎     | 66/151 [02:00<06:56,  4.90s/it]Trying to set attribute `.obs` of view, copying.
#  44%|████▍     | 67/151 [02:00<04:52,  3.48s/it]Trying to set attribute `.obs` of view, copying.
#  45%|████▌     | 68/151 [02:01<03:29,  2.53s/it]Trying to set attribute `.obs` of view, copying.
#  46%|████▌     | 69/151 [02:01<02:35,  1.89s/it]Trying to set attribute `.obs` of view, copying.
#  46%|████▋     | 70/151 [02:03<02:34,  1.91s/it]Trying to set attribute `.obs` of view, copying.
#  47%|████▋     | 71/151 [02:03<01:50,  1.39s/it]Trying to set attribute `.obs` of view, copying.
#  48%|████▊     | 72/151 [02:03<01:21,  1.03s/it]Trying to set attribute `.obs` of view, copying.
#  48%|████▊     | 73/151 [02:04<01:14,  1.05it/s]Trying to set attribute `.obs` of view, copying.
#  49%|████▉     | 74/151 [02:04<00:55,  1.39it/s]Trying to set attribute `.obs` of view, copying.
#  50%|████▉     | 75/151 [02:05<00:42,  1.81it/s]Trying to set attribute `.obs` of view, copying.
#  50%|█████     | 76/151 [02:05<00:32,  2.31it/s]Trying to set attribute `.obs` of view, copying.
#  51%|█████     | 77/151 [02:05<00:26,  2.83it/s]Trying to set attribute `.obs` of view, copying.
#  52%|█████▏    | 78/151 [02:07<01:09,  1.06it/s]Trying to set attribute `.obs` of view, copying.
#  52%|█████▏    | 79/151 [02:11<02:16,  1.90s/it]Trying to set attribute `.obs` of view, copying.
#  53%|█████▎    | 80/151 [02:12<01:44,  1.46s/it]Trying to set attribute `.obs` of view, copying.
#  54%|█████▎    | 81/151 [02:12<01:22,  1.18s/it]Trying to set attribute `.obs` of view, copying.
#  54%|█████▍    | 82/151 [02:13<01:05,  1.06it/s]Trying to set attribute `.obs` of view, copying.
#  55%|█████▍    | 83/151 [02:13<00:52,  1.30it/s]Trying to set attribute `.obs` of view, copying.
#  56%|█████▌    | 84/151 [02:14<00:46,  1.45it/s]Trying to set attribute `.obs` of view, copying.
#  56%|█████▋    | 85/151 [02:14<00:37,  1.76it/s]Trying to set attribute `.obs` of view, copying.
#  57%|█████▋    | 86/151 [02:14<00:34,  1.87it/s]Trying to set attribute `.obs` of view, copying.
#  58%|█████▊    | 87/151 [02:15<00:31,  2.01it/s]Trying to set attribute `.obs` of view, copying.
#  58%|█████▊    | 88/151 [02:15<00:32,  1.95it/s]Trying to set attribute `.obs` of view, copying.
#  59%|█████▉    | 89/151 [02:16<00:30,  2.03it/s]Trying to set attribute `.obs` of view, copying.
#  60%|█████▉    | 90/151 [02:16<00:30,  2.01it/s]Trying to set attribute `.obs` of view, copying.
#  60%|██████    | 91/151 [02:17<00:26,  2.23it/s]Trying to set attribute `.obs` of view, copying.
#  61%|██████    | 92/151 [02:17<00:24,  2.42it/s]Trying to set attribute `.obs` of view, copying.
#  62%|██████▏   | 93/151 [02:17<00:21,  2.72it/s]Trying to set attribute `.obs` of view, copying.
#  62%|██████▏   | 94/151 [02:17<00:20,  2.79it/s]Trying to set attribute `.obs` of view, copying.
#  63%|██████▎   | 95/151 [02:18<00:18,  3.03it/s]Trying to set attribute `.obs` of view, copying.
#  64%|██████▎   | 96/151 [02:18<00:17,  3.15it/s]Trying to set attribute `.obs` of view, copying.
#  64%|██████▍   | 97/151 [02:18<00:17,  3.11it/s]Trying to set attribute `.obs` of view, copying.
#  65%|██████▍   | 98/151 [02:19<00:18,  2.87it/s]Trying to set attribute `.obs` of view, copying.
#  66%|██████▌   | 99/151 [02:19<00:18,  2.82it/s]Trying to set attribute `.obs` of view, copying.
#  66%|██████▌   | 100/151 [02:19<00:17,  2.88it/s]Trying to set attribute `.obs` of view, copying.
#  67%|██████▋   | 101/151 [02:20<00:17,  2.88it/s]Trying to set attribute `.obs` of view, copying.
#  68%|██████▊   | 102/151 [02:20<00:16,  2.98it/s]Trying to set attribute `.obs` of view, copying.
#  68%|██████▊   | 103/151 [02:20<00:13,  3.67it/s]Trying to set attribute `.obs` of view, copying.
#  69%|██████▉   | 104/151 [02:21<00:14,  3.28it/s]Trying to set attribute `.obs` of view, copying.
#  70%|██████▉   | 105/151 [02:21<00:14,  3.12it/s]Trying to set attribute `.obs` of view, copying.
#  70%|███████   | 106/151 [02:21<00:14,  3.13it/s]Trying to set attribute `.obs` of view, copying.
#  71%|███████   | 107/151 [02:22<00:16,  2.63it/s]Trying to set attribute `.obs` of view, copying.
#  72%|███████▏  | 108/151 [02:22<00:15,  2.81it/s]Trying to set attribute `.obs` of view, copying.
#  72%|███████▏  | 109/151 [02:23<00:16,  2.58it/s]Trying to set attribute `.obs` of view, copying.
#  73%|███████▎  | 110/151 [02:23<00:15,  2.71it/s]Trying to set attribute `.obs` of view, copying.
#  74%|███████▎  | 111/151 [02:23<00:14,  2.79it/s]Trying to set attribute `.obs` of view, copying.
#  74%|███████▍  | 112/151 [02:24<00:15,  2.55it/s]Trying to set attribute `.obs` of view, copying.
#  75%|███████▍  | 113/151 [02:24<00:17,  2.17it/s]Trying to set attribute `.obs` of view, copying.
#  75%|███████▌  | 114/151 [02:25<00:15,  2.37it/s]Trying to set attribute `.obs` of view, copying.
#  76%|███████▌  | 115/151 [02:25<00:13,  2.63it/s]Trying to set attribute `.obs` of view, copying.
#  77%|███████▋  | 116/151 [02:25<00:12,  2.76it/s]Trying to set attribute `.obs` of view, copying.
#  77%|███████▋  | 117/151 [02:26<00:11,  3.01it/s]Trying to set attribute `.obs` of view, copying.
#  78%|███████▊  | 118/151 [02:26<00:10,  3.14it/s]Trying to set attribute `.obs` of view, copying.
#  79%|███████▉  | 119/151 [02:26<00:10,  3.15it/s]Trying to set attribute `.obs` of view, copying.
#  79%|███████▉  | 120/151 [02:26<00:09,  3.26it/s]Trying to set attribute `.obs` of view, copying.
#  80%|████████  | 121/151 [02:27<00:09,  3.21it/s]Trying to set attribute `.obs` of view, copying.
#  81%|████████  | 122/151 [02:27<00:08,  3.53it/s]Trying to set attribute `.obs` of view, copying.
#  81%|████████▏ | 123/151 [02:27<00:07,  3.58it/s]Trying to set attribute `.obs` of view, copying.
#  82%|████████▏ | 124/151 [02:28<00:07,  3.45it/s]Trying to set attribute `.obs` of view, copying.
#  83%|████████▎ | 125/151 [02:28<00:07,  3.49it/s]Trying to set attribute `.obs` of view, copying.
#  83%|████████▎ | 126/151 [02:28<00:06,  3.60it/s]Trying to set attribute `.obs` of view, copying.
#  84%|████████▍ | 127/151 [02:29<00:08,  2.86it/s]Trying to set attribute `.obs` of view, copying.
#  85%|████████▍ | 128/151 [02:29<00:08,  2.86it/s]Trying to set attribute `.obs` of view, copying.
#  85%|████████▌ | 129/151 [02:29<00:08,  2.75it/s]Trying to set attribute `.obs` of view, copying.
#  86%|████████▌ | 130/151 [02:30<00:07,  2.88it/s]Trying to set attribute `.obs` of view, copying.
#  87%|████████▋ | 131/151 [02:30<00:06,  3.25it/s]Trying to set attribute `.obs` of view, copying.
#  87%|████████▋ | 132/151 [02:30<00:05,  3.76it/s]Trying to set attribute `.obs` of view, copying.
#  88%|████████▊ | 133/151 [02:31<00:06,  2.96it/s]Trying to set attribute `.obs` of view, copying.
#  89%|████████▊ | 134/151 [02:31<00:05,  2.94it/s]Trying to set attribute `.obs` of view, copying.
#  89%|████████▉ | 135/151 [02:31<00:06,  2.43it/s]Trying to set attribute `.obs` of view, copying.
#  90%|█████████ | 136/151 [02:32<00:07,  1.95it/s]Trying to set attribute `.obs` of view, copying.
#  91%|█████████ | 137/151 [02:33<00:08,  1.62it/s]Trying to set attribute `.obs` of view, copying.
#  91%|█████████▏| 138/151 [02:33<00:06,  1.95it/s]Trying to set attribute `.obs` of view, copying.
#  92%|█████████▏| 139/151 [02:34<00:05,  2.01it/s]Trying to set attribute `.obs` of view, copying.
#  93%|█████████▎| 140/151 [02:34<00:05,  1.96it/s]Trying to set attribute `.obs` of view, copying.
#  93%|█████████▎| 141/151 [02:35<00:04,  2.04it/s]Trying to set attribute `.obs` of view, copying.
#  94%|█████████▍| 142/151 [02:35<00:04,  2.03it/s]Trying to set attribute `.obs` of view, copying.
#  95%|█████████▍| 143/151 [02:35<00:03,  2.50it/s]Trying to set attribute `.obs` of view, copying.
#  95%|█████████▌| 144/151 [02:36<00:03,  2.17it/s]Trying to set attribute `.obs` of view, copying.
#  96%|█████████▌| 145/151 [02:37<00:03,  1.78it/s]Trying to set attribute `.obs` of view, copying.
#  97%|█████████▋| 146/151 [02:38<00:03,  1.58it/s]Trying to set attribute `.obs` of view, copying.
#  97%|█████████▋| 147/151 [02:38<00:02,  1.59it/s]Trying to set attribute `.obs` of view, copying.
#  98%|█████████▊| 148/151 [02:39<00:02,  1.35it/s]Trying to set attribute `.obs` of view, copying.
#  99%|█████████▊| 149/151 [02:40<00:01,  1.57it/s]Trying to set attribute `.obs` of view, copying.
#  99%|█████████▉| 150/151 [02:40<00:00,  1.70it/s]Trying to set attribute `.obs` of view, copying.
# 100%|██████████| 151/151 [02:41<00:00,  1.07s/it]

# %%
for sample_id in tqdm(sample_counts):
    df = sample_counts[sample_id]
#     df.to_df().to_csv(data_path + 'interim/umi_for_classification/' + sample_id + '.csv') # write
    df.to_df().to_hdf(data_path + 'interim/classification_inputs/umi_per_sample.h5', key = sample_id)
# Out:
#   0%|          | 0/151 [00:00<?, ?it/s]/home/hratch/anaconda3/envs/cellchat/lib/python3.9/site-packages/tables/path.py:155: NaturalNameWarning: object name is not a valid Python identifier: 'S-S070-2'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*`; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
#   1%|          | 1/151 [00:12<30:32, 12.22s/it]/home/hratch/anaconda3/envs/cellchat/lib/python3.9/site-packages/tables/path.py:155: NaturalNameWarning: object name is not a valid Python identifier: 'S-S070-3'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
#   2%|▏         | 3/151 [00:21<16:17,  6.61s/it]/home/hratch/anaconda3/envs/cellchat/lib/python3.9/site-packages/tables/path.py:155: NaturalNameWarning: object name is not a valid Python identifier: 'S-M044-1'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
#   3%|▎         | 4/151 [00:28<16:25,  6.70s/it]/home/hratch/anaconda3/envs/cellchat/lib/python3.9/site-packages/tables/path.py:155: NaturalNameWarning: object name is not a valid Python identifier: 'S-M043-1'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
#   5%|▍         | 7/151 [00:49<16:52,  7.03s/it]/home/hratch/anaconda3/envs/cellchat/lib/python3.9/site-packages/tables/path.py:155: NaturalNameWarning: object name is not a valid Python identifier: 'S-M043-2'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
#   6%|▌         | 9/151 [01:04<17:03,  7.21s/it]/home/hratch/anaconda3/envs/cellchat/lib/python3.9/site-packages/tables/path.py:155: NaturalNameWarning: object name is not a valid Python identifier: 'S-S056'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
#   7%|▋         | 10/151 [01:12<17:03,  7.26s/it]/home/hratch/anaconda3/envs/cellchat/lib/python3.9/site-packages/tables/path.py:155: NaturalNameWarning: object name is not a valid Python identifier: 'S-M042-1'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
#  11%|█         | 16/151 [01:46<13:24,  5.96s/it]/home/hratch/anaconda3/envs/cellchat/lib/python3.9/site-packages/tables/path.py:155: NaturalNameWarning: object name is not a valid Python identifier: 'S-S057'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
#  12%|█▏        | 18/151 [01:58<13:36,  6.14s/it]/home/hratch/anaconda3/envs/cellchat/lib/python3.9/site-packages/tables/path.py:155: NaturalNameWarning: object name is not a valid Python identifier: 'S-M041-2'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
#  17%|█▋        | 25/151 [02:42<12:34,  5.99s/it]/home/hratch/anaconda3/envs/cellchat/lib/python3.9/site-packages/tables/path.py:155: NaturalNameWarning: object name is not a valid Python identifier: 'S-M055'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
#  25%|██▍       | 37/151 [04:28<16:02,  8.45s/it]/home/hratch/anaconda3/envs/cellchat/lib/python3.9/site-packages/tables/path.py:155: NaturalNameWarning: object name is not a valid Python identifier: 'S-M052'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
#  25%|██▌       | 38/151 [04:34<14:51,  7.89s/it]/home/hratch/anaconda3/envs/cellchat/lib/python3.9/site-packages/tables/path.py:155: NaturalNameWarning: object name is not a valid Python identifier: 'S-S068'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
#  26%|██▌       | 39/151 [04:41<13:55,  7.46s/it]/home/hratch/anaconda3/envs/cellchat/lib/python3.9/site-packages/tables/path.py:155: NaturalNameWarning: object name is not a valid Python identifier: 'S-S066'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
#  29%|██▉       | 44/151 [05:09<09:49,  5.51s/it]/home/hratch/anaconda3/envs/cellchat/lib/python3.9/site-packages/tables/path.py:155: NaturalNameWarning: object name is not a valid Python identifier: 'S-S062'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
#  30%|██▉       | 45/151 [05:13<08:44,  4.94s/it]/home/hratch/anaconda3/envs/cellchat/lib/python3.9/site-packages/tables/path.py:155: NaturalNameWarning: object name is not a valid Python identifier: 'S-S063'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
#  30%|███       | 46/151 [05:17<08:08,  4.66s/it]/home/hratch/anaconda3/envs/cellchat/lib/python3.9/site-packages/tables/path.py:155: NaturalNameWarning: object name is not a valid Python identifier: 'S-S035-3'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
#  31%|███       | 47/151 [05:20<07:13,  4.16s/it]/home/hratch/anaconda3/envs/cellchat/lib/python3.9/site-packages/tables/path.py:155: NaturalNameWarning: object name is not a valid Python identifier: 'S-S035-4'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
#  33%|███▎      | 50/151 [05:38<10:16,  6.11s/it]/home/hratch/anaconda3/envs/cellchat/lib/python3.9/site-packages/tables/path.py:155: NaturalNameWarning: object name is not a valid Python identifier: 'S-M066'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
#  35%|███▌      | 53/151 [06:04<11:36,  7.10s/it]/home/hratch/anaconda3/envs/cellchat/lib/python3.9/site-packages/tables/path.py:155: NaturalNameWarning: object name is not a valid Python identifier: 'S-S090-2'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
#  39%|███▉      | 59/151 [07:14<18:32, 12.09s/it]/home/hratch/anaconda3/envs/cellchat/lib/python3.9/site-packages/tables/path.py:155: NaturalNameWarning: object name is not a valid Python identifier: 'S-S089-2'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
#  44%|████▎     | 66/151 [08:24<12:32,  8.85s/it]/home/hratch/anaconda3/envs/cellchat/lib/python3.9/site-packages/tables/path.py:155: NaturalNameWarning: object name is not a valid Python identifier: 'S-M025'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
#  48%|████▊     | 72/151 [08:57<07:28,  5.67s/it]/home/hratch/anaconda3/envs/cellchat/lib/python3.9/site-packages/tables/path.py:155: NaturalNameWarning: object name is not a valid Python identifier: 'S-M027'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
#  50%|████▉     | 75/151 [09:12<06:29,  5.13s/it]/home/hratch/anaconda3/envs/cellchat/lib/python3.9/site-packages/tables/path.py:155: NaturalNameWarning: object name is not a valid Python identifier: 'S-M026-2'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
#  50%|█████     | 76/151 [09:16<06:03,  4.85s/it]/home/hratch/anaconda3/envs/cellchat/lib/python3.9/site-packages/tables/path.py:155: NaturalNameWarning: object name is not a valid Python identifier: 'S-M026-3'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
#  52%|█████▏    | 78/151 [09:30<07:32,  6.20s/it]/home/hratch/anaconda3/envs/cellchat/lib/python3.9/site-packages/tables/path.py:155: NaturalNameWarning: object name is not a valid Python identifier: 'S-M011'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
#  52%|█████▏    | 79/151 [09:40<08:35,  7.15s/it]/home/hratch/anaconda3/envs/cellchat/lib/python3.9/site-packages/tables/path.py:155: NaturalNameWarning: object name is not a valid Python identifier: 'S-M012'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
#  54%|█████▍    | 82/151 [10:04<08:58,  7.81s/it]/home/hratch/anaconda3/envs/cellchat/lib/python3.9/site-packages/tables/path.py:155: NaturalNameWarning: object name is not a valid Python identifier: 'S-S013'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
#  55%|█████▍    | 83/151 [10:10<08:03,  7.10s/it]/home/hratch/anaconda3/envs/cellchat/lib/python3.9/site-packages/tables/path.py:155: NaturalNameWarning: object name is not a valid Python identifier: 'S-S014'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
#  56%|█████▋    | 85/151 [10:21<06:49,  6.20s/it]/home/hratch/anaconda3/envs/cellchat/lib/python3.9/site-packages/tables/path.py:155: NaturalNameWarning: object name is not a valid Python identifier: 'S-S016'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
#  58%|█████▊    | 88/151 [10:43<07:18,  6.96s/it]/home/hratch/anaconda3/envs/cellchat/lib/python3.9/site-packages/tables/path.py:155: NaturalNameWarning: object name is not a valid Python identifier: 'S-S019'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
#  62%|██████▏   | 93/151 [11:22<07:09,  7.40s/it]/home/hratch/anaconda3/envs/cellchat/lib/python3.9/site-packages/tables/path.py:155: NaturalNameWarning: object name is not a valid Python identifier: 'S-M023'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
#  63%|██████▎   | 95/151 [11:37<07:11,  7.71s/it]/home/hratch/anaconda3/envs/cellchat/lib/python3.9/site-packages/tables/path.py:155: NaturalNameWarning: object name is not a valid Python identifier: 'S-M024'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
#  66%|██████▌   | 99/151 [12:13<07:37,  8.79s/it]/home/hratch/anaconda3/envs/cellchat/lib/python3.9/site-packages/tables/path.py:155: NaturalNameWarning: object name is not a valid Python identifier: 'S-M021'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
#  72%|███████▏  | 109/151 [13:50<08:02, 11.48s/it]/home/hratch/anaconda3/envs/cellchat/lib/python3.9/site-packages/tables/path.py:155: NaturalNameWarning: object name is not a valid Python identifier: 'S-M037'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
#  73%|███████▎  | 110/151 [14:00<07:37, 11.15s/it]/home/hratch/anaconda3/envs/cellchat/lib/python3.9/site-packages/tables/path.py:155: NaturalNameWarning: object name is not a valid Python identifier: 'S-M038'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
#  74%|███████▎  | 111/151 [14:10<07:10, 10.76s/it]/home/hratch/anaconda3/envs/cellchat/lib/python3.9/site-packages/tables/path.py:155: NaturalNameWarning: object name is not a valid Python identifier: 'S-M039-1'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
#  74%|███████▍  | 112/151 [14:24<07:31, 11.59s/it]/home/hratch/anaconda3/envs/cellchat/lib/python3.9/site-packages/tables/path.py:155: NaturalNameWarning: object name is not a valid Python identifier: 'S-M040-1'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
#  84%|████████▍ | 127/151 [16:14<02:43,  6.81s/it]/home/hratch/anaconda3/envs/cellchat/lib/python3.9/site-packages/tables/path.py:155: NaturalNameWarning: object name is not a valid Python identifier: 'S-S077'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
#  86%|████████▌ | 130/151 [16:34<02:16,  6.50s/it]/home/hratch/anaconda3/envs/cellchat/lib/python3.9/site-packages/tables/path.py:155: NaturalNameWarning: object name is not a valid Python identifier: 'S-S080'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
#  87%|████████▋ | 131/151 [16:39<02:00,  6.05s/it]/home/hratch/anaconda3/envs/cellchat/lib/python3.9/site-packages/tables/path.py:155: NaturalNameWarning: object name is not a valid Python identifier: 'S-S081'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
#  88%|████████▊ | 133/151 [16:51<01:55,  6.44s/it]/home/hratch/anaconda3/envs/cellchat/lib/python3.9/site-packages/tables/path.py:155: NaturalNameWarning: object name is not a valid Python identifier: 'S-S083'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*`; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
#  89%|████████▊ | 134/151 [16:58<01:51,  6.54s/it]/home/hratch/anaconda3/envs/cellchat/lib/python3.9/site-packages/tables/path.py:155: NaturalNameWarning: object name is not a valid Python identifier: 'S-S084'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
#  90%|█████████ | 136/151 [17:19<02:09,  8.67s/it]/home/hratch/anaconda3/envs/cellchat/lib/python3.9/site-packages/tables/path.py:155: NaturalNameWarning: object name is not a valid Python identifier: 'S-S038'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
#  91%|█████████ | 137/151 [17:32<02:20, 10.03s/it]/home/hratch/anaconda3/envs/cellchat/lib/python3.9/site-packages/tables/path.py:155: NaturalNameWarning: object name is not a valid Python identifier: 'S-S040'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
#  92%|█████████▏| 139/151 [17:48<01:48,  9.07s/it]/home/hratch/anaconda3/envs/cellchat/lib/python3.9/site-packages/tables/path.py:155: NaturalNameWarning: object name is not a valid Python identifier: 'S-S042'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
#  99%|█████████▉| 150/151 [19:46<00:11, 11.08s/it]/home/hratch/anaconda3/envs/cellchat/lib/python3.9/site-packages/tables/path.py:155: NaturalNameWarning: object name is not a valid Python identifier: 'S-S053'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# 100%|██████████| 151/151 [20:07<00:00,  8.00s/it]
